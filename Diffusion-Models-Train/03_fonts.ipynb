# %%
import wandb
from utils import get_alphabet
from ddpm_conditional import *

# %%
run = wandb.init(project="train_fonts", job_type="evaluate")
artifact = run.use_artifact('945096249-sjtu-hpc-center/train_fonts/model:v10', type='model')
artifact_dir = artifact.download()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/estar/.netrc.
# wandb: Currently logged in as: 945096249 (945096249-sjtu-hpc-center) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/estar/TZ/AI-L/MY_GM/Diffusion-Models-Train/wandb/run-20260129_135527-2ymj76xg</code>
# Syncing run <strong><a href='https://wandb.ai/945096249-sjtu-hpc-center/train_fonts/runs/2ymj76xg' target="_blank">sparkling-feather-1</a></strong> to <a href='https://wandb.ai/945096249-sjtu-hpc-center/train_fonts' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/945096249-sjtu-hpc-center/train_fonts' target="_blank">https://wandb.ai/945096249-sjtu-hpc-center/train_fonts</a>
#  View run at <a href='https://wandb.ai/945096249-sjtu-hpc-center/train_fonts/runs/2ymj76xg' target="_blank">https://wandb.ai/945096249-sjtu-hpc-center/train_fonts/runs/2ymj76xg</a>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/apis/normalize.py:28, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      27 try:
# ---> 28     return func(*args, **kwargs)
#      30 except requests.HTTPError as error:
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/apis/public/api.py:1494, in Api._artifact(self, name, type, enable_tracking)
#    1493 path = FullArtifactPath(prefix=entity, project=project, name=artifact_name)
# -> 1494 artifact = Artifact._from_name(
#    1495     path=path,
#    1496     client=self.client,
#    1497     enable_tracking=enable_tracking,
#    1498 )
#    1499 if type is not None and artifact.type != type:
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/sdk/artifacts/artifact.py:326, in Artifact._from_name(cls, path, client, enable_tracking)
#     325 if server_supports(client, pb.PROJECT_ARTIFACT_COLLECTION_MEMBERSHIP):
# --> 326     return cls._membership_from_name(path=path, client=client)
#     328 gql_vars = {
#     329     "entity": path.prefix,
#     330     "project": path.project,
#     331     "name": path.name,
#     332     "enableTracking": enable_tracking,
#     333 }
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/sdk/artifacts/artifact.py:311, in Artifact._membership_from_name(cls, path, client)
#     310     msg = f"artifact membership {path.name!r} not found in {entity_project!r}"
# --> 311     raise ValueError(msg)
#     313 return cls._from_membership(membership, target=path, client=client)
#
# ValueError: artifact membership 'model:v10' not found in '945096249-sjtu-hpc-center/train_fonts'
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 run = wandb.init(project="train_fonts", job_type="evaluate")
# ----> 2 artifact = run.use_artifact('945096249-sjtu-hpc-center/train_fonts/model:v10', type='model')
#       3 artifact_dir = artifact.download()
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:400, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     397     run_id = self._attach_id
#     399 with wb_logging.log_to_run(run_id):
# --> 400     return func(self, *args, **kwargs)
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:458, in _raise_if_finished.<locals>.wrapper_fn(self, *args, **kwargs)
#     455 @functools.wraps(func)
#     456 def wrapper_fn(self: Run, *args: _P.args, **kwargs: _P.kwargs) -> _T:
#     457     if not getattr(self, "_is_finished", False):
# --> 458         return func(self, *args, **kwargs)
#     460     message = (
#     461         f"Run ({self.id}) is finished. The call to"
#     462         f" `{func.__name__}` will be ignored."
#     463         f" Please make sure that you are using an active run."
#     464     )
#     466     raise UsageError(message)
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:445, in _attach.<locals>.wrapper(self, *args, **kwargs)
#     442     finally:
#     443         _is_attaching = ""
# --> 445 return func(self, *args, **kwargs)
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:3094, in Run.use_artifact(self, artifact_or_name, type, aliases, use_as)
#    3092 name = artifact_or_name
#    3093 public_api = self._public_api()
# -> 3094 artifact = public_api._artifact(type=type, name=name)
#    3095 if type is not None and type != artifact.type:
#    3096     raise ValueError(
#    3097         f"Supplied type {type} does not match type {artifact.type} of artifact {artifact.name}"
#    3098     )
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/apis/normalize.py:82, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      80     raise
#      81 else:
# ---> 82     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/apis/normalize.py:28, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      26 message = "Whoa, you found a bug."
#      27 try:
# ---> 28     return func(*args, **kwargs)
#      30 except requests.HTTPError as error:
#      31     errors = parse_backend_error_messages(error.response)
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/apis/public/api.py:1494, in Api._artifact(self, name, type, enable_tracking)
#    1489     raise ValueError(
#    1490         "Could not determine entity. Please include the entity as part of the artifact name path."
#    1491     )
#    1493 path = FullArtifactPath(prefix=entity, project=project, name=artifact_name)
# -> 1494 artifact = Artifact._from_name(
#    1495     path=path,
#    1496     client=self.client,
#    1497     enable_tracking=enable_tracking,
#    1498 )
#    1499 if type is not None and artifact.type != type:
#    1500     raise ValueError(
#    1501         f"type {type} specified but this artifact is of type {artifact.type}"
#    1502     )
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/sdk/artifacts/artifact.py:326, in Artifact._from_name(cls, path, client, enable_tracking)
#     323 from ._generated import ARTIFACT_BY_NAME_GQL, ArtifactByName
#     325 if server_supports(client, pb.PROJECT_ARTIFACT_COLLECTION_MEMBERSHIP):
# --> 326     return cls._membership_from_name(path=path, client=client)
#     328 gql_vars = {
#     329     "entity": path.prefix,
#     330     "project": path.project,
#     331     "name": path.name,
#     332     "enableTracking": enable_tracking,
#     333 }
#     334 gql_op = gql(ARTIFACT_BY_NAME_GQL)
#
# File ~/TZ/python_env/torch-light/lib/python3.9/site-packages/wandb/sdk/artifacts/artifact.py:311, in Artifact._membership_from_name(cls, path, client)
#     309     entity_project = f"{path.prefix}/{path.project}"
#     310     msg = f"artifact membership {path.name!r} not found in {entity_project!r}"
# --> 311     raise ValueError(msg)
#     313 return cls._from_membership(membership, target=path, client=client)
#
# CommError: artifact membership 'model:v10' not found in '945096249-sjtu-hpc-center/train_fonts'
